# %% [markdown]
# # CMI Behavior Detection with Multimodal V40 (ws64 & ws128 ensemble)
#
# This notebook uses an ensemble of two 5-fold multimodal models (window size 64 and 128) for gesture recognition. The predictions from both model sets are averaged to produce the final result.

# %%
import os
from pathlib import Path
import polars as pl

import kaggle_evaluation.cmi_inference_server

from src.inference_pipeline import predict_one

# %%
def predict(sequence: pl.DataFrame, demographics: pl.DataFrame) -> str:
    return predict_one(sequence, demographics)

# %%
inference_server = kaggle_evaluation.cmi_inference_server.CMIInferenceServer(predict)

def is_kaggle():
    return "KAGGLE_URL_BASE" in os.environ or Path("/kaggle").exists()

if os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
    inference_server.serve()
else:
    if is_kaggle():
        inference_server.run_local_gateway(
            data_paths=(
                '/kaggle/input/cmi-detect-behavior-with-sensor-data/test.csv',
                '/kaggle/input/cmi-detect-behavior-with-sensor-data/test_demographics.csv',
            )
        )
    else:
        inference_server.run_local_gateway(
            data_paths=(
                '../data/split/test.csv',
                '../data/split/test_demographics.csv',
            )
        )
# Out:
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/kaggle_evaluation/core/templates.py:136: RuntimeWarning: 1014 seconds elapsed before server startup.
#                 This exceeds the startup time limit of 900 seconds that the gateway will enforce
#                 during the rerun on the hidden test set. Start the server before performing any time consuming steps.
#   warnings.warn(
# INFO:src.inference_pipeline:Starting ensemble inference for one sample.
# INFO:src.inference_pipeline:Processing with ws64 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (66, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 64, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 64, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (132, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値21,016個, 欠損値21,224個
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値20,212個, 欠損値20,748個
# INFO:utils.pipeline:Output shapes: windows=(2, 64, 18), demographics=(2, 7), tabular=(2, 429), tof=(132, 5, 8, 8), tof_win=(2, 64, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws64 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Processing with ws128 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (66, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 128, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (132, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値21,016個, 欠損値21,224個
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値21,016個, 欠損値60,904個
# INFO:utils.pipeline:Output shapes: windows=(2, 128, 18), demographics=(2, 7), tabular=(2, 429), tof=(132, 5, 8, 8), tof_win=(2, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws128 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Ensemble prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Final predicted label: Text on phone
# INFO:src.inference_pipeline:Starting ensemble inference for one sample.
# INFO:src.inference_pipeline:Processing with ws64 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (71, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 64, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 64, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (142, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値34,340個, 欠損値11,100個
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値30,700個, 欠損値10,260個
# INFO:utils.pipeline:Output shapes: windows=(2, 64, 18), demographics=(2, 7), tabular=(2, 429), tof=(142, 5, 8, 8), tof_win=(2, 64, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws64 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Processing with ws128 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (71, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 128, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (142, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値34,340個, 欠損値11,100個
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値34,340個, 欠損値47,580個
# INFO:utils.pipeline:Output shapes: windows=(2, 128, 18), demographics=(2, 7), tabular=(2, 429), tof=(142, 5, 8, 8), tof_win=(2, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws128 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Ensemble prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Final predicted label: Above ear - pull hair
# INFO:src.inference_pipeline:Starting ensemble inference for one sample.
# INFO:src.inference_pipeline:Processing with ws64 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (48, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 64, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 64, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (96, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値3,082個, 欠損値27,638個
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値3,082個, 欠損値37,878個
# INFO:utils.pipeline:Output shapes: windows=(2, 64, 18), demographics=(2, 7), tabular=(2, 429), tof=(96, 5, 8, 8), tof_win=(2, 64, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws64 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Processing with ws128 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (48, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 128, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (96, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値3,082個, 欠損値27,638個
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値3,082個, 欠損値78,838個
# INFO:utils.pipeline:Output shapes: windows=(2, 128, 18), demographics=(2, 7), tabular=(2, 429), tof=(96, 5, 8, 8), tof_win=(2, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws128 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Ensemble prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Final predicted label: Eyelash - pull hair
# INFO:src.inference_pipeline:Starting ensemble inference for one sample.
# INFO:src.inference_pipeline:Processing with ws64 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (56, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 64, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 64, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (112, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値29,240個, 欠損値6,600個
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値29,240個, 欠損値11,720個
# INFO:utils.pipeline:Output shapes: windows=(2, 64, 18), demographics=(2, 7), tabular=(2, 429), tof=(112, 5, 8, 8), tof_win=(2, 64, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws64 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Processing with ws128 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (56, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 128, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (112, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値29,240個, 欠損値6,600個
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値29,240個, 欠損値52,680個
# INFO:utils.pipeline:Output shapes: windows=(2, 128, 18), demographics=(2, 7), tabular=(2, 429), tof=(112, 5, 8, 8), tof_win=(2, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws128 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Ensemble prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Final predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting ensemble inference for one sample.
# INFO:src.inference_pipeline:Processing with ws64 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (55, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 64, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 64, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (110, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値22,850個, 欠損値12,350個
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値22,850個, 欠損値18,110個
# INFO:utils.pipeline:Output shapes: windows=(2, 64, 18), demographics=(2, 7), tabular=(2, 429), tof=(110, 5, 8, 8), tof_win=(2, 64, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws64 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Processing with ws128 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (55, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 128, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (110, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値22,850個, 欠損値12,350個
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値22,850個, 欠損値59,070個
# INFO:utils.pipeline:Output shapes: windows=(2, 128, 18), demographics=(2, 7), tabular=(2, 429), tof=(110, 5, 8, 8), tof_win=(2, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws128 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Ensemble prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Final predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting ensemble inference for one sample.
# INFO:src.inference_pipeline:Processing with ws64 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (54, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 64, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 64, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (108, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値28,384個, 欠損値6,176個
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値28,384個, 欠損値12,576個
# INFO:utils.pipeline:Output shapes: windows=(2, 64, 18), demographics=(2, 7), tabular=(2, 429), tof=(108, 5, 8, 8), tof_win=(2, 64, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws64 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Processing with ws128 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (54, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 128, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (108, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値28,384個, 欠損値6,176個
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値28,384個, 欠損値53,536個
# INFO:utils.pipeline:Output shapes: windows=(2, 128, 18), demographics=(2, 7), tabular=(2, 429), tof=(108, 5, 8, 8), tof_win=(2, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws128 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Ensemble prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Final predicted label: Forehead - pull hairline
# INFO:src.inference_pipeline:Starting ensemble inference for one sample.
# INFO:src.inference_pipeline:Processing with ws64 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (53, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 64, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 64, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (106, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値28,144個, 欠損値5,776個
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 64, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値28,144個, 欠損値12,816個
# INFO:utils.pipeline:Output shapes: windows=(2, 64, 18), demographics=(2, 7), tabular=(2, 429), tof=(106, 5, 8, 8), tof_win=(2, 64, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws64 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Processing with ws128 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (53, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 128, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# ✅ TDA処理前: NaN値なし
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (106, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値28,144個, 欠損値5,776個
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値28,144個, 欠損値53,776個
# INFO:utils.pipeline:Output shapes: windows=(2, 128, 18), demographics=(2, 7), tabular=(2, 429), tof=(106, 5, 8, 8), tof_win=(2, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:ws128 prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Ensemble prediction completed. Shape: (2, 18)
# INFO:src.inference_pipeline:Final predicted label: Forehead - pull hairline
# INFO:src.inference_pipeline:Starting ensemble inference for one sample.
# INFO:src.inference_pipeline:Processing with ws64 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (117, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(4, 64, 18), X_demo=(4, 7), y=(4,)
# INFO:utils.pipeline:Window tensor shape (4, 64, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (4, 64, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (4, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (234, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値38,624個, 欠損値36,256個
# INFO:utils.pipeline:Building ToF windows (size=64, stride=32, min_len=20)
# INFO:utils.pipeline:ToF windows shape (4, 64, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値38,474個, 欠損値43,446個
# INFO:utils.pipeline:Output shapes: windows=(4, 64, 18), demographics=(4, 7), tabular=(4, 429), tof=(234, 5, 8, 8), tof_win=(4, 64, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws64 prediction completed. Shape: (4, 18)
# INFO:src.inference_pipeline:Processing with ws128 preprocessor...
# INFO:utils.pipeline:Transforming dataframe of shape (117, 343)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/utils/feature_engineering.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[flag] = df[cols].isna().all(axis=1)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 128, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True, tof_event=True, temp_grad=True)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:Tabular features shape (2, 429)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (234, 5, 8, 8)
# INFO:utils.pipeline:ToF正規化完了: 有効値38,624個, 欠損値36,256個
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:ToF Windows正規化完了: 有効値38,624個, 欠損値43,296個
# INFO:utils.pipeline:Output shapes: windows=(2, 128, 18), demographics=(2, 7), tabular=(2, 429), tof=(234, 5, 8, 8), tof_win=(2, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:ws128 prediction completed. Shape: (2, 18)
# ERROR:grpc._server:Exception calling application: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# Traceback (most recent call last):
#   File "/mnt/c/Users/ShunK/works/CMI_comp/.venv/lib/python3.11/site-packages/grpc/_server.py", line 610, in _call_behavior
#     response_or_iterator = behavior(argument, context)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/kaggle_evaluation/core/relay.py", line 354, in Send
#     response_payload = _serialize(response_function(*args, **kwargs))
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_185934/132370808.py", line 2, in predict
#     return predict_one(sequence, demographics)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/src/inference_pipeline.py", line 145, in predict_one
#     final_avg_pred = np.mean(all_final_preds, axis=0)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/c/Users/ShunK/works/CMI_comp/.venv/lib/python3.11/site-packages/numpy/core/fromnumeric.py", line 3504, in mean
#     return _methods._mean(a, axis=axis, dtype=dtype,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/c/Users/ShunK/works/CMI_comp/.venv/lib/python3.11/site-packages/numpy/core/_methods.py", line 102, in _mean
#     arr = asanyarray(a)
#           ^^^^^^^^^^^^^
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.
# ---------------------------------------------------------------------------
# GatewayRuntimeError                       Traceback (most recent call last)
# Cell In[7], line 17
#      10     inference_server.run_local_gateway(
#      11         data_paths=(
#      12             '/kaggle/input/cmi-detect-behavior-with-sensor-data/test.csv',
#      13             '/kaggle/input/cmi-detect-behavior-with-sensor-data/test_demographics.csv',
#      14         )
#      15     )
#      16 else:
# ---> 17     inference_server.run_local_gateway(
#      18         data_paths=(
#      19             '../data/split/test.csv',
#      20             '../data/split/test_demographics.csv',
#      21         )
#      22     )
#
# File /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/kaggle_evaluation/core/templates.py:149, in InferenceServer.run_local_gateway(self, data_paths, file_share_dir, *args, **kwargs)
#     147     self.gateway.run()
#     148 except Exception as err:
# --> 149     raise err from None
#     150 finally:
#     151     self.server.stop(0)
#
# File /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/kaggle_evaluation/core/templates.py:147, in InferenceServer.run_local_gateway(self, data_paths, file_share_dir, *args, **kwargs)
#     145 try:
#     146     self.gateway = self._get_gateway_for_test(data_paths, file_share_dir, *args, **kwargs)
# --> 147     self.gateway.run()
#     148 except Exception as err:
#     149     raise err from None
#
# File /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/kaggle_evaluation/core/templates.py:105, in Gateway.run(self)
#     102     self.write_result(error)
#     103 elif error:
#     104     # For local testing
# --> 105     raise error
#
# File /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/kaggle_evaluation/core/templates.py:84, in Gateway.run(self)
#      82 try:
#      83     self.unpack_data_paths()
# ---> 84     predictions, row_ids = self.get_all_predictions()
#      85     self.write_submission(predictions, row_ids)
#      86 except kaggle_evaluation.core.base_gateway.GatewayRuntimeError as gre:
#
# File /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/kaggle_evaluation/core/templates.py:56, in Gateway.get_all_predictions(self)
#      54 all_row_ids = []
#      55 for data_batch, row_ids in self.generate_data_batches():
# ---> 56     predictions = self.predict(*data_batch)
#      57     self.validate_prediction_batch(predictions, row_ids)
#      58     all_predictions.append(predictions)
#
# File /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/kaggle_evaluation/core/templates.py:72, in Gateway.predict(self, *args, **kwargs)
#      70     return self.client.send('predict', *args, **kwargs)
#      71 except Exception as e:
# ---> 72     self.handle_server_error(e, 'predict')
#
# File /mnt/c/Users/ShunK/works/CMI_comp/submissions/v40_64and128/kaggle_evaluation/core/base_gateway.py:257, in BaseGateway.handle_server_error(self, exception, endpoint)
#     255     message_match = re.search('"Exception calling application: (.*)"', exception_str, re.IGNORECASE)
#     256     message = message_match.group(1) if message_match else exception_str
# --> 257     raise GatewayRuntimeError(GatewayRuntimeErrorType.SERVER_RAISED_EXCEPTION, message) from None
#     258 if isinstance(exception, grpc._channel._InactiveRpcError):
#     259     raise GatewayRuntimeError(GatewayRuntimeErrorType.SERVER_CONNECTION_FAILED, exception_str) from None
#
# GatewayRuntimeError: (<GatewayRuntimeErrorType.SERVER_RAISED_EXCEPTION: 3>, 'setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.')

# %%
# Check submission file
import pandas as pd
df = pd.read_parquet('submission.parquet')
print('Shape:', df.shape)
print('Columns:', df.columns.tolist())
print('First 10 rows:')
print(df.head(10))
print('Value counts:')
print(df['gesture'].value_counts())
# Out:
# Shape: (102, 2)
# Columns: ['sequence_id', 'gesture']
# First 10 rows:
#   sequence_id                    gesture
# 0  SEQ_060707         Cheek - pinch skin
# 1  SEQ_037923              Text on phone
# 2  SEQ_028006   Forehead - pull hairline
# 3  SEQ_020034      Above ear - pull hair
# 4  SEQ_016979        Eyebrow - pull hair
# 5  SEQ_037140      Above ear - pull hair
# 6  SEQ_062937             Neck - scratch
# 7  SEQ_025391          Neck - pinch skin
# 8  SEQ_064204  Pull air toward your face
# 9  SEQ_063950         Cheek - pinch skin
# Value counts:
# gesture
# Neck - scratch                                20
# Cheek - pinch skin                            13
# Neck - pinch skin                             13
# Text on phone                                 11
# Wave hello                                     7
# Eyebrow - pull hair                            6
# Eyelash - pull hair                            6
# Above ear - pull hair                          5
# Forehead - scratch                             5
# Forehead - pull hairline                       3
# Pull air toward your face                      3
# Glasses on/off                                 3
# Pinch knee/leg skin                            3
# Write name in air                              2
# Feel around in tray and pull out an object     1
# Write name on leg                              1
# Name: count, dtype: int64

# %%
import pandas as pd
from src.utils.cmi_evaluation import calculate_cmi_score

# 例: 推論結果
df_pred = pd.read_parquet('submission.parquet')  # またはcsv等
# 例: 正解ラベル
df_true = pd.read_csv('../data/split/test_labels.csv')

# ラベル名が一致している前提
y_pred = df_pred['gesture'].values
y_true = df_true['gesture'].values

# 必要ならLabelEncoderでエンコード
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(list(y_true) + list(y_pred))
y_true_enc = le.transform(y_true)
y_pred_enc = le.transform(y_pred)

# CMIスコア計算
cmi_score, binary_f1, macro_f1, test_acc = calculate_cmi_score(y_pred_enc, y_true_enc, label_encoder=le, verbose=True)
print(f'CMI Score: {cmi_score:.4f}, Binary F1: {binary_f1:.4f}, Macro F1: {macro_f1:.4f}, Accuracy: {test_acc:.4f}')
# Out:
# CMI評価指標計算開始...
# y_true shape: (102,), y_pred shape: (102,)
# ラベル変換完了: 102 samples
# データ中のジェスチャー: 18種類
# Binary分類 - Target: 64, Non-Target: 38
# Binary F1: 0.6963
# Macro F1: 0.1124
# CMI Score: 0.4044
# Test Accuracy: 0.0588
# CMI Score: 0.4044, Binary F1: 0.6963, Macro F1: 0.1124, Accuracy: 0.0588

# %%
# Out:
# Target / Non‑target 比率 (%)
# sequence_type  Non-Target  Target
# fold
# 0                    39.7    60.3
# 1                    40.4    59.6
# 2                    40.3    59.7
# 3                    40.4    59.6
# 4                    40.0    60.0
