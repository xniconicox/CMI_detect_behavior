# %%
import os
from pathlib import Path
import polars as pl

import kaggle_evaluation.cmi_inference_server

from src.inference_pipeline import predict_one
# Out:
# 2025-07-18 16:28:05.028225: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-18 16:28:06.651229: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752823687.168873 1049079 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752823687.308485 1049079 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752823688.532799 1049079 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752823688.532845 1049079 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752823688.532846 1049079 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752823688.532848 1049079 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-18 16:28:08.652484: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:src.inference_pipeline:Loading preprocessor and model...
# INFO:src.utils.pipeline:Loading Preprocessor from models/preprocessor.pkl
# 実験名: multimodal
# データディレクトリ: output/experiments/multimodal/preprocessed
# I0000 00:00:1752823710.003949 1049079 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5660 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6
# INFO:src.inference_pipeline:Label mapping: {'Above ear - pull hair': 0, 'Cheek - pinch skin': 1, 'Drink from bottle/cup': 2, 'Eyebrow - pull hair': 3, 'Eyelash - pull hair': 4, 'Feel around in tray and pull out an object': 5, 'Forehead - pull hairline': 6, 'Forehead - scratch': 7, 'Glasses on/off': 8, 'Neck - pinch skin': 9, 'Neck - scratch': 10, 'Pinch knee/leg skin': 11, 'Pull air toward your face': 12, 'Scratch knee/leg skin': 13, 'Text on phone': 14, 'Wave hello': 15, 'Write name in air': 16, 'Write name on leg': 17}
# INFO:src.inference_pipeline:Number of classes: 18
# INFO:src.inference_pipeline:Model and preprocessor loaded successfully

# %%
def predict(sequence: pl.DataFrame, demographics: pl.DataFrame) -> str:
    return predict_one(sequence, demographics)

# %%
inference_server = kaggle_evaluation.cmi_inference_server.CMIInferenceServer(predict)

def is_kaggle():
    # Kaggle環境ではこの環境変数が必ず存在
    return "KAGGLE_URL_BASE" in os.environ or Path("/kaggle").exists()

if os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
    inference_server.serve()
else:
    
    if is_kaggle():
        inference_server.run_local_gateway(
            data_paths=(
                '/kaggle/input/cmi-detect-behavior-with-sensor-data/test.csv',
                '/kaggle/input/cmi-detect-behavior-with-sensor-data/test_demographics.csv',
            )
        )
    else:
        inference_server.run_local_gateway(
            data_paths=(
                # '../../data/test.csv',
                # '../../data/test_demographics.csv',
                # '../data/split/train_val.csv',
                # '../data/split/train_val_demographics.csv',
                '../data/split/test.csv',
                '../data/split/test_demographics.csv',
                # '../../data/train.csv',
                # '../../data/train_demographics.csv',
            )
        )
# Out:
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (103, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (103, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (103, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(103, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# I0000 00:00:1752823718.483900 1049251 cuda_dnn.cc:529] Loaded cuDNN version 90501
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (56, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (56, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (56, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(56, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (77, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (77, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (77, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(77, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Wave hello
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (59, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (59, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (59, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(59, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (79, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (79, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (79, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(79, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (72, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (72, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (72, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(72, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Text on phone
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (57, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (57, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (57, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(57, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (54, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (54, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (54, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(54, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (55, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (55, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (55, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(55, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Text on phone
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (90, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (90, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (90, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(90, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Pinch knee/leg skin
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (87, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (87, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (87, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(87, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Above ear - pull hair
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (58, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (58, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (58, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(58, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (80, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (80, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (80, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(80, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (64, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (64, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (64, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(64, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Glasses on/off
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (91, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (91, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (91, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(91, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Wave hello
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (82, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (82, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (82, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(82, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Eyelash - pull hair
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (54, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (54, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (54, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(54, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Eyelash - pull hair
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (63, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (63, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (63, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(63, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Above ear - pull hair
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (53, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (53, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (53, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(53, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (53, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (53, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (53, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(53, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (52, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (52, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (52, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(52, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Eyelash - pull hair
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (71, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (71, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (71, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(71, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Above ear - pull hair
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (56, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (56, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (56, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(56, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Text on phone
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (53, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (53, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (53, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(53, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Eyelash - pull hair
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (77, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (77, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (77, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(77, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (117, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (117, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (117, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(117, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Eyelash - pull hair
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (88, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (88, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (88, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(88, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (71, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (71, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (71, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(71, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (60, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (60, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (60, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(60, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Text on phone
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (84, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (84, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (84, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(84, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Text on phone
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (70, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (70, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (70, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(70, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (100, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (100, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (100, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(100, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (55, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (55, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (55, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(55, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (54, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (54, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (54, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(54, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Forehead - scratch
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (52, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (52, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (52, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(52, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Above ear - pull hair
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (98, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (98, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (84, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# ✅ TDA処理前: NaN値なし
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(84, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (90, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (90, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (90, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(90, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Eyelash - pull hair
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (81, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (81, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (81, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(81, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Eyelash - pull hair
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (70, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (70, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (70, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(70, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Glasses on/off
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (58, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (58, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (58, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(58, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Eyebrow - pull hair
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (53, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (53, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (53, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(53, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (57, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (57, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# ✅ TDA処理前: NaN値なし
# INFO:src.utils.pipeline:ToF voxel shape (57, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(57, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Eyelash - pull hair
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (57, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (57, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (57, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(57, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (54, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (54, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (54, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(54, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Drink from bottle/cup
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (61, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (61, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (61, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(61, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (57, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (57, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (57, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(57, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Forehead - scratch
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (95, 343)
# INFO:src.inference_pipeline:['SUBJ_032165']
# INFO:src.utils.pipeline:Transforming dataframe of shape (95, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:src.utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:src.utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:src.utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:src.utils.pipeline:Tabular features shape (1, 389)
# INFO:src.utils.pipeline:Building ToF voxel tensor
# INFO:src.utils.pipeline:ToF voxel shape (95, 5, 8, 8)
# INFO:src.utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:src.utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(95, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:src.utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Text on phone
# ✅ TDA処理前: NaN値なし

# %%
import pandas as pd
df = pd.read_parquet('submission.parquet')
print('Shape:', df.shape)
print('Columns:', df.columns.tolist())
print('First 10 rows:')
print(df.head(10))
print('Value counts:')
print(df['gesture'].value_counts())
# Out:
# Shape: (102, 2)
# Columns: ['sequence_id', 'gesture']
# First 10 rows:
#   sequence_id              gesture
# 0  SEQ_038473       Neck - scratch
# 1  SEQ_031219       Neck - scratch
# 2  SEQ_007712           Wave hello
# 3  SEQ_020956    Neck - pinch skin
# 4  SEQ_062937       Neck - scratch
# 5  SEQ_051747        Text on phone
# 6  SEQ_025391    Neck - pinch skin
# 7  SEQ_063950    Neck - pinch skin
# 8  SEQ_049859        Text on phone
# 9  SEQ_049982  Pinch knee/leg skin
# Value counts:
# gesture
# Neck - scratch           25
# Neck - pinch skin        16
# Eyelash - pull hair      15
# Text on phone            12
# Wave hello                8
# Above ear - pull hair     7
# Pinch knee/leg skin       5
# Forehead - scratch        4
# Write name in air         4
# Glasses on/off            2
# Scratch knee/leg skin     1
# Cheek - pinch skin        1
# Eyebrow - pull hair       1
# Drink from bottle/cup     1
# Name: count, dtype: int64

# %%
import pandas as pd
from src.utils.cmi_evaluation import calculate_cmi_score

# 例: 推論結果
df_pred = pd.read_parquet('submission.parquet')  # またはcsv等
# 例: 正解ラベル
df_true = pd.read_csv('../data/split/test_labels.csv')

# ラベル名が一致している前提
y_pred = df_pred['gesture'].values
y_true = df_true['gesture'].values

# 必要ならLabelEncoderでエンコード
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(list(y_true) + list(y_pred))
y_true_enc = le.transform(y_true)
y_pred_enc = le.transform(y_pred)

# CMIスコア計算
cmi_score, binary_f1, macro_f1, test_acc = calculate_cmi_score(y_pred_enc, y_true_enc, label_encoder=le, verbose=True)
print(f'CMI Score: {cmi_score:.4f}, Binary F1: {binary_f1:.4f}, Macro F1: {macro_f1:.4f}, Accuracy: {test_acc:.4f}')
# Out:
# CMI評価指標計算開始...
# y_true shape: (102,), y_pred shape: (102,)
# ラベル変換完了: 102 samples
# データ中のジェスチャー: 18種類
# Binary分類 - Target: 64, Non-Target: 38
# Binary F1: 0.6617
# Macro F1: 0.0788
# CMI Score: 0.3703
# Test Accuracy: 0.0294
# CMI Score: 0.3703, Binary F1: 0.6617, Macro F1: 0.0788, Accuracy: 0.0294
