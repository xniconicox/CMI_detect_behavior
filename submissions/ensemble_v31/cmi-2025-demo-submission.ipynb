# %% [markdown]
# # CMI Behavior Detection with Multimodal V30 (5-fold Ensemble)
#
# This notebook uses a 5-fold ensemble of multimodal models (IMU, demographics, tabular features, and ToF voxels) for gesture recognition.

# %%
import os
from pathlib import Path
import polars as pl

import kaggle_evaluation.cmi_inference_server

from src.inference_pipeline import predict_one
# Out:
# INFO:src.inference_pipeline:Loading preprocessor and models...
# INFO:utils.pipeline:Loading Preprocessor from preprocessed/preprocessor.pkl
# INFO:src.inference_pipeline:Loading model: models/multimodal_model_v31_fold1.keras
# I0000 00:00:1752973638.185456 1312953 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5660 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6
# INFO:src.inference_pipeline:Loading model: models/multimodal_model_v31_fold2.keras
# INFO:src.inference_pipeline:Loading model: models/multimodal_model_v31_fold3.keras
# INFO:src.inference_pipeline:Loading model: models/multimodal_model_v31_fold4.keras
# INFO:src.inference_pipeline:Loading model: models/multimodal_model_v31_fold5.keras
# INFO:src.inference_pipeline:Loaded 5 models successfully.
# INFO:src.inference_pipeline:Label mapping: {'Above ear - pull hair': 0, 'Cheek - pinch skin': 1, 'Drink from bottle/cup': 2, 'Eyebrow - pull hair': 3, 'Eyelash - pull hair': 4, 'Feel around in tray and pull out an object': 5, 'Forehead - pull hairline': 6, 'Forehead - scratch': 7, 'Glasses on/off': 8, 'Neck - pinch skin': 9, 'Neck - scratch': 10, 'Pinch knee/leg skin': 11, 'Pull air toward your face': 12, 'Scratch knee/leg skin': 13, 'Text on phone': 14, 'Wave hello': 15, 'Write name in air': 16, 'Write name on leg': 17}
# INFO:src.inference_pipeline:Number of classes: 18

# %%
def predict(sequence: pl.DataFrame, demographics: pl.DataFrame) -> str:
    return predict_one(sequence, demographics)

# %%
inference_server = kaggle_evaluation.cmi_inference_server.CMIInferenceServer(predict)

def is_kaggle():
    return "KAGGLE_URL_BASE" in os.environ or Path("/kaggle").exists()

if os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
    inference_server.serve()
else:
    if is_kaggle():
        inference_server.run_local_gateway(
            data_paths=(
                '/kaggle/input/cmi-detect-behavior-with-sensor-data/test.csv',
                '/kaggle/input/cmi-detect-behavior-with-sensor-data/test_demographics.csv',
            )
        )
    else:
        inference_server.run_local_gateway(
            data_paths=(
                '../data/split/test.csv',
                '../data/split/test_demographics.csv',
            )
        )
# Out:
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (57, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (57, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (57, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(57, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# I0000 00:00:1752973680.495598 1314132 cuda_dnn.cc:529] Loaded cuDNN version 90501
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fc92c198400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fc92c198400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (98, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (98, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (98, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(98, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Wave hello
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (61, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (61, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (61, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(61, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (117, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (117, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (117, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(117, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (69, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (69, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (69, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(69, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Cheek - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (82, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (82, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (82, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(82, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Cheek - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (55, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (55, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (55, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(55, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (84, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (84, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (84, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(84, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (88, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (88, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (88, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(88, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (82, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (82, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (82, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(82, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Forehead - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (56, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (56, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (56, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(56, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Wave hello
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (52, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (52, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (52, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(52, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Cheek - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (58, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (58, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (58, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(58, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Eyelash - pull hair
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (54, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (54, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (54, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(54, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Eyelash - pull hair
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (55, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (55, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (55, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(55, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (57, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (57, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (57, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(57, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (84, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (84, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (84, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(84, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Text on phone
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (53, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (53, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (53, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# ✅ TDA処理前: NaN値なし
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(53, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Cheek - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (90, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (90, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (90, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(90, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Scratch knee/leg skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (52, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (52, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (52, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(52, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Write name in air
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (98, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (98, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (98, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(98, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (210, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (210, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(2, 128, 18), X_demo=(2, 7), y=(2,)
# INFO:utils.pipeline:Window tensor shape (2, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (2, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (210, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (2, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(2, 128, 18), demographics=(2, 7), tabular=(2, 389), tof=(210, 5, 8, 8), tof_win=(2, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (2, 128, 18), Demo: (2, 7), Tabular: (2, 389), ToF: (2, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# WARNING:tensorflow:5 out of the last 105 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fc9bc165760> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 105 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fc9bc165760> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:src.inference_pipeline:Predicted 2 labels
# INFO:src.inference_pipeline:Predicted label: Text on phone
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (57, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (57, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (57, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(57, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (87, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (87, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (87, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# ✅ TDA処理前: NaN値なし
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(87, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (54, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (54, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (54, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(54, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Forehead - pull hairline
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (55, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (55, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (55, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(55, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Pull air toward your face
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (66, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (66, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (66, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(66, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Text on phone
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (48, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (48, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (48, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(48, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Eyelash - pull hair
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (64, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (64, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (64, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(64, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Glasses on/off
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (53, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (53, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (53, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(53, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Pinch knee/leg skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (52, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (52, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (52, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(52, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Cheek - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (53, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (53, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (53, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(53, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (88, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (88, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (88, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(88, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (57, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (57, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (57, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(57, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Forehead - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (89, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (89, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (89, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(89, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Write name in air
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (77, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (77, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# ...
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (58, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(58, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (56, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (56, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (56, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(56, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (98, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (98, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (98, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(98, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (90, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (90, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (90, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(90, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (71, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (71, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (71, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(71, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Wave hello
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (50, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (50, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (50, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(50, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Pinch knee/leg skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (58, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (58, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (58, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(58, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (87, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (87, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (87, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(87, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (53, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (53, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (53, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(53, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (57, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (57, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (57, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(57, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Pull air toward your face
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (66, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (66, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (66, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(66, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (70, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (70, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (70, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(70, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - scratch
# INFO:src.inference_pipeline:Starting inference for one sample
# INFO:src.inference_pipeline:Combined data shape: (53, 343)
# INFO:utils.pipeline:Transforming dataframe of shape (53, 343)
# interp:   0%|          | 0/1 [00:00<?, ?seq/s]
# concat:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:utils.pipeline:Building windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:Windows shapes: X_sensor=(1, 128, 18), X_demo=(1, 7), y=(1,)
# INFO:utils.pipeline:Window tensor shape (1, 128, 18)
# INFO:utils.pipeline:Building tabular features (wavelet=True, tda=True)
# INFO:utils.pipeline:Tabular features shape (1, 389)
# INFO:utils.pipeline:Building ToF voxel tensor
# INFO:utils.pipeline:ToF voxel shape (53, 5, 8, 8)
# INFO:utils.pipeline:Building ToF windows (size=128, stride=64, min_len=20)
# INFO:utils.pipeline:ToF windows shape (1, 128, 5, 8, 8)
# INFO:utils.pipeline:Output shapes: windows=(1, 128, 18), demographics=(1, 7), tabular=(1, 389), tof=(53, 5, 8, 8), tof_win=(1, 128, 5, 8, 8)
# INFO:utils.pipeline:testデータのため、ラベルエンコーディングをスキップ
# INFO:src.inference_pipeline:Input shapes - Sensor: (1, 128, 18), Demo: (1, 7), Tabular: (1, 389), ToF: (1, 128, 5, 8, 8)
# ✅ TDA処理前: NaN値なし
# INFO:src.inference_pipeline:Predicted 1 labels
# INFO:src.inference_pipeline:Predicted label: Neck - pinch skin

# %%
# Check submission file
import pandas as pd
df = pd.read_parquet('submission.parquet')
print('Shape:', df.shape)
print('Columns:', df.columns.tolist())
print('First 10 rows:')
print(df.head(10))
print('Value counts:')
print(df['gesture'].value_counts())
# Out:
# Shape: (102, 2)
# Columns: ['sequence_id', 'gesture']
# First 10 rows:
#   sequence_id             gesture
# 0  SEQ_025391   Neck - pinch skin
# 1  SEQ_038757          Wave hello
# 2  SEQ_015201   Neck - pinch skin
# 3  SEQ_039212      Neck - scratch
# 4  SEQ_061117  Cheek - pinch skin
# 5  SEQ_024191  Cheek - pinch skin
# 6  SEQ_060217   Neck - pinch skin
# 7  SEQ_028272      Neck - scratch
# 8  SEQ_057603      Neck - scratch
# 9  SEQ_027256  Forehead - scratch
# Value counts:
# gesture
# Neck - scratch                                27
# Neck - pinch skin                             18
# Text on phone                                  8
# Wave hello                                     7
# Cheek - pinch skin                             6
# Forehead - pull hairline                       5
# Forehead - scratch                             5
# Eyelash - pull hair                            5
# Pull air toward your face                      4
# Write name in air                              4
# Scratch knee/leg skin                          3
# Glasses on/off                                 3
# Pinch knee/leg skin                            2
# Eyebrow - pull hair                            2
# Above ear - pull hair                          1
# Write name on leg                              1
# Feel around in tray and pull out an object     1
# Name: count, dtype: int64

# %%
import pandas as pd
from src.utils.cmi_evaluation import calculate_cmi_score

# 例: 推論結果
df_pred = pd.read_parquet('submission.parquet')  # またはcsv等
# 例: 正解ラベル
df_true = pd.read_csv('../data/split/test_labels.csv')

# ラベル名が一致している前提
y_pred = df_pred['gesture'].values
y_true = df_true['gesture'].values

# 必要ならLabelEncoderでエンコード
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(list(y_true) + list(y_pred))
y_true_enc = le.transform(y_true)
y_pred_enc = le.transform(y_pred)

# CMIスコア計算
cmi_score, binary_f1, macro_f1, test_acc = calculate_cmi_score(y_pred_enc, y_true_enc, label_encoder=le, verbose=True)
print(f'CMI Score: {cmi_score:.4f}, Binary F1: {binary_f1:.4f}, Macro F1: {macro_f1:.4f}, Accuracy: {test_acc:.4f}')
# Out:
# CMI評価指標計算開始...
# y_true shape: (102,), y_pred shape: (102,)
# ラベル変換完了: 102 samples
# データ中のジェスチャー: 18種類
# Binary分類 - Target: 64, Non-Target: 38
# Binary F1: 0.6165
# Macro F1: 0.1026
# CMI Score: 0.3596
# Test Accuracy: 0.0686
# CMI Score: 0.3596, Binary F1: 0.6165, Macro F1: 0.1026, Accuracy: 0.0686

# %%
# Out:
# Target / Non‑target 比率 (%)
# sequence_type  Non-Target  Target
# fold
# 0                    39.7    60.3
# 1                    40.4    59.6
# 2                    40.3    59.7
# 3                    40.4    59.6
# 4                    40.0    60.0
